# %%
# !pip install -U google-genai
from google import genai

# %%
client = genai.Client(api_key="AQ.Ab8RN6K8yL8bs1cbq4xjep3bH8cgZAxyAIqyFIBwvaYL5hr8Gw")

MODEL = "models/gemini-3.5-flash"

# %%
while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)

# %%
# !pip install -U google-genai
from google import genai

# %%
client = genai.Client(api_key="AQ.Ab8RN6K8yL8bs1cbq4xjep3bH8cgZAxyAIqyFIBwvaYL5hr8Gw")

# %%
MODEL = "models/gemini-3.5-flash"

# %%
def smart_parking_agent(user_input):

    prompt = f"""
You are a professional Smart Parking Agent.

Your task is to help users find suitable parking and provide useful parking information.

Provide a well-structured response with clear headings:

1. Parking Availability
2. Nearest Parking Location
3. Estimated Parking Cost
4. Available Parking Duration
5. Parking Instructions and Tips

Make the response detailed but easy for students to understand.

User request: {user_input}

Smart Parking Response:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text


print("Gemini Smart Parking Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye")
        break

    try:
        reply = smart_parking_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Gemini Smart Parking Agent Started (type 'exit' to stop)
#
# You: exit
# Goodbye
